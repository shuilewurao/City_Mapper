# %% [markdown]
# <a href="https://colab.research.google.com/github/shuilewurao/City_Mapper/blob/master/baseline/gamenet/GAMENet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/UIUC/spring2022/GAMENet/code
# !ls
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/UIUC/spring2022/GAMENet/code
# baseline    layers.py  __pycache__  train_GAMENet.py
# deplicated  models.py  saved	    util.py
# /content/drive/MyDrive/UIUC/spring2022/GAMENet/code

# %%
# !pip install dnc
# Out:
# Collecting dnc
#   Downloading dnc-1.1.0-py3-none-any.whl (20 kB)
# Collecting flann
#   Downloading flann-1.6.13-py3-none-any.whl (24 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from dnc) (1.11.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dnc) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->dnc) (4.2.0)
# Installing collected packages: flann, dnc
# Successfully installed dnc-1.1.0 flann-1.6.13

# %%
import torch
import argparse
import numpy as np
import dill
import time
from torch.nn import CrossEntropyLoss
from torch.optim import Adam
import os
import torch.nn.functional as F
from collections import defaultdict

from models import GAMENet
from util import llprint, multi_label_metric, ddi_rate_score, get_n_params

torch.manual_seed(1203)
np.random.seed(1203)

model_name = 'GAMENet'
#resume_name = ''
resume_name = 'saved/{}/Epoch_49_TARGET_0.06_JA_0.5099_DDI_0.06283.model'.format(model_name)

if not os.path.exists(os.path.join("saved", model_name)):
        os.makedirs(os.path.join("saved", model_name))

# %%
# Training settings
parser = argparse.ArgumentParser()
parser.add_argument('--eval', action='store_true', default=False, help="eval mode")
parser.add_argument('--model_name', type=str, default=model_name, help="model name")
parser.add_argument('--resume_path', type=str, default=resume_name, help='resume path')
parser.add_argument('--ddi', action='store_true', default=False, help="using ddi")

#args = parser.parse_args()
args = parser.parse_args(args=[])
#model_name = args.model_name
#resume_name = args.resume_path

# %%
def eval(model, data_eval, voc_size, epoch):
    # evaluate
    print('')
    model.eval()
    smm_record = []
    ja, prauc, avg_p, avg_r, avg_f1 = [[] for _ in range(5)]
    case_study = defaultdict(dict)
    med_cnt = 0
    visit_cnt = 0
    for step, input in enumerate(data_eval):
        y_gt = []
        y_pred = []
        y_pred_prob = []
        y_pred_label = []
        for adm_idx, adm in enumerate(input):

            target_output1 = model(input[:adm_idx+1])

            y_gt_tmp = np.zeros(voc_size[2])
            y_gt_tmp[adm[2]] = 1
            y_gt.append(y_gt_tmp)

            target_output1 = F.sigmoid(target_output1).detach().cpu().numpy()[0]
            y_pred_prob.append(target_output1)
            y_pred_tmp = target_output1.copy()
            y_pred_tmp[y_pred_tmp>=0.5] = 1
            y_pred_tmp[y_pred_tmp<0.5] = 0
            y_pred.append(y_pred_tmp)
            y_pred_label_tmp = np.where(y_pred_tmp == 1)[0]
            y_pred_label.append(sorted(y_pred_label_tmp))
            visit_cnt += 1
            med_cnt += len(y_pred_label_tmp)


        smm_record.append(y_pred_label)
        adm_ja, adm_prauc, adm_avg_p, adm_avg_r, adm_avg_f1 = multi_label_metric(np.array(y_gt), np.array(y_pred), np.array(y_pred_prob))
        case_study[adm_ja] = {'ja': adm_ja, 'patient': input, 'y_label': y_pred_label}

        ja.append(adm_ja)
        prauc.append(adm_prauc)
        avg_p.append(adm_avg_p)
        avg_r.append(adm_avg_r)
        avg_f1.append(adm_avg_f1)
        llprint('\rEval--Epoch: %d, Step: %d/%d' % (epoch, step, len(data_eval)))

    # ddi rate
    ddi_rate = ddi_rate_score(smm_record)

    llprint('\tDDI Rate: %.4f, Jaccard: %.4f,  PRAUC: %.4f, AVG_PRC: %.4f, AVG_RECALL: %.4f, AVG_F1: %.4f\n' % (
        ddi_rate, np.mean(ja), np.mean(prauc), np.mean(avg_p), np.mean(avg_r), np.mean(avg_f1)
    ))
    dill.dump(obj=smm_record, file=open('../data/gamenet_records.pkl', 'wb'))
    dill.dump(case_study, open(os.path.join('saved', model_name, 'case_study.pkl'), 'wb'))

    # print('avg med', med_cnt / visit_cnt)

    return ddi_rate, np.mean(ja), np.mean(prauc), np.mean(avg_p), np.mean(avg_r), np.mean(avg_f1)


def main():
    if not os.path.exists(os.path.join("saved", model_name)):
        os.makedirs(os.path.join("saved", model_name))

    data_path = '../data/records_final.pkl'
    voc_path = '../data/voc_final.pkl'

    ehr_adj_path = '../data/ehr_adj_final.pkl'
    ddi_adj_path = '../data/ddi_A_final.pkl'
    device = torch.device('cuda:0')

    ehr_adj = dill.load(open(ehr_adj_path, 'rb'))
    ddi_adj = dill.load(open(ddi_adj_path, 'rb'))
    data = dill.load(open(data_path, 'rb'))
    voc = dill.load(open(voc_path, 'rb'))
    diag_voc, pro_voc, med_voc = voc['diag_voc'], voc['pro_voc'], voc['med_voc']

    split_point = int(len(data) * 2 / 3)
    data_train = data[:split_point]
    eval_len = int(len(data[split_point:]) / 2)
    data_test = data[split_point:split_point + eval_len]
    data_eval = data[split_point+eval_len:]

    EPOCH = 50
    LR = 0.0002
    TEST = args.eval
    Neg_Loss = args.ddi
    DDI_IN_MEM = args.ddi
    TARGET_DDI = 0.06
    T = 0.5
    decay_weight = 0.85

    voc_size = (len(diag_voc.idx2word), len(pro_voc.idx2word), len(med_voc.idx2word))
    model = GAMENet(voc_size, ehr_adj, ddi_adj, emb_dim=64, device=device, ddi_in_memory=DDI_IN_MEM)
    if TEST:
        model.load_state_dict(torch.load(open(resume_name, 'rb')))
    model.to(device=device)

    print('parameters', get_n_params(model))
    optimizer = Adam(list(model.parameters()), lr=LR)

    if TEST:
        eval(model, data_test, voc_size, 0)
    else:
        history = defaultdict(list)
        best_epoch = 0
        best_ja = 0
        for epoch in range(EPOCH):
            
            tic = time.time()
            
            loss_record1 = []
            start_time = time.time()
            model.train()
            prediction_loss_cnt = 0
            neg_loss_cnt = 0
            for step, input in enumerate(data_train):
                for idx, adm in enumerate(input):
                    seq_input = input[:idx+1]
                    loss1_target = np.zeros((1, voc_size[2]))
                    loss1_target[:, adm[2]] = 1
                    loss3_target = np.full((1, voc_size[2]), -1)
                    for idx, item in enumerate(adm[2]):
                        loss3_target[0][idx] = item

                    target_output1, batch_neg_loss = model(seq_input)

                    loss1 = F.binary_cross_entropy_with_logits(target_output1, torch.FloatTensor(loss1_target).to(device))
                    loss3 = F.multilabel_margin_loss(F.sigmoid(target_output1), torch.LongTensor(loss3_target).to(device))
                    if Neg_Loss:
                        target_output1 = F.sigmoid(target_output1).detach().cpu().numpy()[0]
                        target_output1[target_output1 >= 0.5] = 1
                        target_output1[target_output1 < 0.5] = 0
                        y_label = np.where(target_output1 == 1)[0]
                        current_ddi_rate = ddi_rate_score([[y_label]])
                        if current_ddi_rate <= TARGET_DDI:
                            loss = 0.9 * loss1 + 0.01 * loss3
                            prediction_loss_cnt += 1
                        else:
                            rnd = np.exp((TARGET_DDI - current_ddi_rate)/T)
                            if np.random.rand(1) < rnd:
                                loss = batch_neg_loss
                                neg_loss_cnt += 1
                            else:
                                loss = 0.9 * loss1 + 0.01 * loss3
                                prediction_loss_cnt += 1
                    else:
                        loss = 0.9 * loss1 + 0.01 * loss3

                    optimizer.zero_grad()
                    loss.backward(retain_graph=True)
                    optimizer.step()

                    loss_record1.append(loss.item())

                llprint('\rTrain--Epoch: %d, Step: %d/%d, L_p cnt: %d, L_neg cnt: %d' % (epoch, step, len(data_train), prediction_loss_cnt, neg_loss_cnt))
            tic2 = time.time()
            # annealing
            T *= decay_weight

            ddi_rate, ja, prauc, avg_p, avg_r, avg_f1 = eval(model, data_eval, voc_size, epoch)

            print ('training time: {}, test time: {}'.format(time.time() - tic, time.time() - tic2))

            history['ja'].append(ja)
            history['ddi_rate'].append(ddi_rate)
            history['avg_p'].append(avg_p)
            history['avg_r'].append(avg_r)
            history['avg_f1'].append(avg_f1)
            history['prauc'].append(prauc)
            history['train_time'].append(time.time() - tic)
            history['memory'].append(torch.cuda.memory_allocated(0)/1024/1024)

            end_time = time.time()
            elapsed_time = (end_time - start_time) / 60
            llprint('\tEpoch: %d, Loss: %.4f, One Epoch Time: %.2fm, Appro Left Time: %.2fh\n' % (epoch,
                                                                                                np.mean(loss_record1),
                                                                                                elapsed_time,
                                                                                                elapsed_time * (
                                                                                                            EPOCH - epoch - 1)/60))

            torch.save(model.state_dict(), open( os.path.join('saved', model_name, 'Epoch_%d_JA_%.4f_DDI_%.4f.model' % (epoch, ja, ddi_rate)), 'wb'))
            print('')
            if epoch != 0 and best_ja < ja:
                best_epoch = epoch
                best_ja = ja


        dill.dump(history, open(os.path.join('saved', model_name, 'history.pkl'), 'wb'))

        # test
        torch.save(model.state_dict(), open(
            os.path.join('saved', model_name, 'final.model'), 'wb'))

        print('best_epoch:', best_epoch)


if __name__ == '__main__':
    main()
# Out:
# parameters 455002
# Train--Epoch: 0, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 0, Step: 1058/1059	DDI Rate: 0.0708, Jaccard: 0.4327,  PRAUC: 0.7070, AVG_PRC: 0.6401, AVG_RECALL: 0.5919, AVG_F1: 0.5965
# training time: 88.37853646278381, test time: 15.456365823745728
# 	Epoch: 0, Loss: 0.3036, One Epoch Time: 1.47m, Appro Left Time: 1.20h
#
# Train--Epoch: 1, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 1, Step: 1058/1059	DDI Rate: 0.0749, Jaccard: 0.4640,  PRAUC: 0.7268, AVG_PRC: 0.6745, AVG_RECALL: 0.6095, AVG_F1: 0.6244
# training time: 86.10791826248169, test time: 13.850031614303589
# 	Epoch: 1, Loss: 0.2861, One Epoch Time: 1.44m, Appro Left Time: 1.15h
#
# Train--Epoch: 2, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 2, Step: 1058/1059	DDI Rate: 0.0743, Jaccard: 0.4717,  PRAUC: 0.7334, AVG_PRC: 0.6787, AVG_RECALL: 0.6149, AVG_F1: 0.6311
# training time: 86.37870168685913, test time: 13.946049213409424
# 	Epoch: 2, Loss: 0.2740, One Epoch Time: 1.44m, Appro Left Time: 1.13h
#
# Train--Epoch: 3, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 3, Step: 1058/1059	DDI Rate: 0.0787, Jaccard: 0.4769,  PRAUC: 0.7378, AVG_PRC: 0.6848, AVG_RECALL: 0.6175, AVG_F1: 0.6360
# training time: 87.24394345283508, test time: 14.25434947013855
# 	Epoch: 3, Loss: 0.2671, One Epoch Time: 1.45m, Appro Left Time: 1.11h
#
# Train--Epoch: 4, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 4, Step: 1058/1059	DDI Rate: 0.0785, Jaccard: 0.4817,  PRAUC: 0.7425, AVG_PRC: 0.6869, AVG_RECALL: 0.6241, AVG_F1: 0.6408
# training time: 88.07535648345947, test time: 14.269583940505981
# 	Epoch: 4, Loss: 0.2621, One Epoch Time: 1.47m, Appro Left Time: 1.10h
#
# Train--Epoch: 5, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 5, Step: 1058/1059	DDI Rate: 0.0815, Jaccard: 0.4894,  PRAUC: 0.7466, AVG_PRC: 0.6866, AVG_RECALL: 0.6370, AVG_F1: 0.6479
# training time: 87.73025250434875, test time: 14.420948266983032
# 	Epoch: 5, Loss: 0.2577, One Epoch Time: 1.46m, Appro Left Time: 1.07h
#
# Train--Epoch: 6, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 6, Step: 1058/1059	DDI Rate: 0.0832, Jaccard: 0.4921,  PRAUC: 0.7495, AVG_PRC: 0.6926, AVG_RECALL: 0.6369, AVG_F1: 0.6504
# training time: 88.58765006065369, test time: 14.429624557495117
# 	Epoch: 6, Loss: 0.2544, One Epoch Time: 1.48m, Appro Left Time: 1.06h
#
# Train--Epoch: 7, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 7, Step: 1058/1059	DDI Rate: 0.0845, Jaccard: 0.4964,  PRAUC: 0.7527, AVG_PRC: 0.6926, AVG_RECALL: 0.6441, AVG_F1: 0.6543
# training time: 89.77603721618652, test time: 14.600037336349487
# 	Epoch: 7, Loss: 0.2518, One Epoch Time: 1.50m, Appro Left Time: 1.05h
#
# Train--Epoch: 8, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 8, Step: 1058/1059	DDI Rate: 0.0842, Jaccard: 0.4979,  PRAUC: 0.7549, AVG_PRC: 0.6969, AVG_RECALL: 0.6435, AVG_F1: 0.6558
# training time: 88.63493514060974, test time: 14.214424848556519
# 	Epoch: 8, Loss: 0.2494, One Epoch Time: 1.48m, Appro Left Time: 1.01h
#
# Train--Epoch: 9, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 9, Step: 1058/1059	DDI Rate: 0.0839, Jaccard: 0.5012,  PRAUC: 0.7574, AVG_PRC: 0.6901, AVG_RECALL: 0.6550, AVG_F1: 0.6589
# training time: 89.03141975402832, test time: 14.460813760757446
# 	Epoch: 9, Loss: 0.2473, One Epoch Time: 1.48m, Appro Left Time: 0.99h
#
# Train--Epoch: 10, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 10, Step: 1058/1059	DDI Rate: 0.0849, Jaccard: 0.5005,  PRAUC: 0.7596, AVG_PRC: 0.6959, AVG_RECALL: 0.6484, AVG_F1: 0.6582
# training time: 88.54383516311646, test time: 14.446522951126099
# 	Epoch: 10, Loss: 0.2455, One Epoch Time: 1.48m, Appro Left Time: 0.96h
#
# Train--Epoch: 11, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 11, Step: 1058/1059	DDI Rate: 0.0855, Jaccard: 0.5037,  PRAUC: 0.7614, AVG_PRC: 0.6944, AVG_RECALL: 0.6549, AVG_F1: 0.6611
# training time: 88.36726331710815, test time: 14.192459106445312
# 	Epoch: 11, Loss: 0.2435, One Epoch Time: 1.47m, Appro Left Time: 0.93h
#
# Train--Epoch: 12, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 12, Step: 1058/1059	DDI Rate: 0.0854, Jaccard: 0.5055,  PRAUC: 0.7618, AVG_PRC: 0.6886, AVG_RECALL: 0.6629, AVG_F1: 0.6626
# training time: 88.85801243782043, test time: 14.427274703979492
# 	Epoch: 12, Loss: 0.2415, One Epoch Time: 1.48m, Appro Left Time: 0.91h
#
# Train--Epoch: 13, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 13, Step: 1058/1059	DDI Rate: 0.0862, Jaccard: 0.5052,  PRAUC: 0.7631, AVG_PRC: 0.6938, AVG_RECALL: 0.6584, AVG_F1: 0.6623
# training time: 88.98030281066895, test time: 14.335909843444824
# 	Epoch: 13, Loss: 0.2403, One Epoch Time: 1.48m, Appro Left Time: 0.89h
#
# Train--Epoch: 14, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 14, Step: 1058/1059	DDI Rate: 0.0840, Jaccard: 0.5069,  PRAUC: 0.7634, AVG_PRC: 0.6926, AVG_RECALL: 0.6629, AVG_F1: 0.6639
# training time: 88.64438104629517, test time: 14.414595127105713
# 	Epoch: 14, Loss: 0.2387, One Epoch Time: 1.48m, Appro Left Time: 0.86h
#
# Train--Epoch: 15, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 15, Step: 1058/1059	DDI Rate: 0.0847, Jaccard: 0.5078,  PRAUC: 0.7643, AVG_PRC: 0.6875, AVG_RECALL: 0.6686, AVG_F1: 0.6646
# training time: 88.81919264793396, test time: 14.391746520996094
# 	Epoch: 15, Loss: 0.2373, One Epoch Time: 1.48m, Appro Left Time: 0.84h
#
# Train--Epoch: 16, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 16, Step: 1058/1059	DDI Rate: 0.0839, Jaccard: 0.5100,  PRAUC: 0.7647, AVG_PRC: 0.6890, AVG_RECALL: 0.6717, AVG_F1: 0.6667
# training time: 89.45421695709229, test time: 14.593839883804321
# 	Epoch: 16, Loss: 0.2360, One Epoch Time: 1.49m, Appro Left Time: 0.82h
#
# Train--Epoch: 17, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 17, Step: 1058/1059	DDI Rate: 0.0844, Jaccard: 0.5106,  PRAUC: 0.7657, AVG_PRC: 0.6815, AVG_RECALL: 0.6792, AVG_F1: 0.6671
# training time: 90.14273738861084, test time: 14.625864267349243
# 	Epoch: 17, Loss: 0.2346, One Epoch Time: 1.50m, Appro Left Time: 0.80h
#
# Train--Epoch: 18, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 18, Step: 1058/1059	DDI Rate: 0.0843, Jaccard: 0.5109,  PRAUC: 0.7657, AVG_PRC: 0.6838, AVG_RECALL: 0.6780, AVG_F1: 0.6673
# training time: 89.98886775970459, test time: 14.599757194519043
# 	Epoch: 18, Loss: 0.2334, One Epoch Time: 1.50m, Appro Left Time: 0.77h
#
# Train--Epoch: 19, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 19, Step: 1058/1059	DDI Rate: 0.0823, Jaccard: 0.5131,  PRAUC: 0.7661, AVG_PRC: 0.6760, AVG_RECALL: 0.6896, AVG_F1: 0.6694
# training time: 90.96759724617004, test time: 14.747117757797241
# 	Epoch: 19, Loss: 0.2322, One Epoch Time: 1.52m, Appro Left Time: 0.76h
#
# Train--Epoch: 20, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 20, Step: 1058/1059	DDI Rate: 0.0828, Jaccard: 0.5127,  PRAUC: 0.7669, AVG_PRC: 0.6812, AVG_RECALL: 0.6840, AVG_F1: 0.6689
# training time: 90.56204891204834, test time: 14.765573024749756
# 	Epoch: 20, Loss: 0.2308, One Epoch Time: 1.51m, Appro Left Time: 0.73h
#
# Train--Epoch: 21, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 21, Step: 1058/1059	DDI Rate: 0.0833, Jaccard: 0.5124,  PRAUC: 0.7673, AVG_PRC: 0.6838, AVG_RECALL: 0.6806, AVG_F1: 0.6685
# training time: 91.35393381118774, test time: 14.956438779830933
# 	Epoch: 21, Loss: 0.2299, One Epoch Time: 1.52m, Appro Left Time: 0.71h
#
# Train--Epoch: 22, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 22, Step: 1058/1059	DDI Rate: 0.0818, Jaccard: 0.5141,  PRAUC: 0.7675, AVG_PRC: 0.6780, AVG_RECALL: 0.6887, AVG_F1: 0.6700
# training time: 90.8741466999054, test time: 14.92776608467102
# 	Epoch: 22, Loss: 0.2286, One Epoch Time: 1.51m, Appro Left Time: 0.68h
#
# Train--Epoch: 23, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 23, Step: 1058/1059	DDI Rate: 0.0814, Jaccard: 0.5148,  PRAUC: 0.7684, AVG_PRC: 0.6762, AVG_RECALL: 0.6926, AVG_F1: 0.6707
# training time: 90.86136889457703, test time: 14.865164518356323
# 	Epoch: 23, Loss: 0.2275, One Epoch Time: 1.51m, Appro Left Time: 0.66h
#
# Train--Epoch: 24, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 24, Step: 1058/1059	DDI Rate: 0.0821, Jaccard: 0.5131,  PRAUC: 0.7673, AVG_PRC: 0.6796, AVG_RECALL: 0.6869, AVG_F1: 0.6693
# training time: 90.72810387611389, test time: 14.78743863105774
# 	Epoch: 24, Loss: 0.2266, One Epoch Time: 1.51m, Appro Left Time: 0.63h
#
# Train--Epoch: 25, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 25, Step: 1058/1059	DDI Rate: 0.0799, Jaccard: 0.5144,  PRAUC: 0.7687, AVG_PRC: 0.6733, AVG_RECALL: 0.6949, AVG_F1: 0.6704
# training time: 90.72574377059937, test time: 14.953319787979126
# 	Epoch: 25, Loss: 0.2254, One Epoch Time: 1.51m, Appro Left Time: 0.60h
#
# Train--Epoch: 26, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 26, Step: 1058/1059	DDI Rate: 0.0818, Jaccard: 0.5141,  PRAUC: 0.7683, AVG_PRC: 0.6751, AVG_RECALL: 0.6925, AVG_F1: 0.6702
# training time: 91.38317680358887, test time: 14.746877431869507
# 	Epoch: 26, Loss: 0.2245, One Epoch Time: 1.52m, Appro Left Time: 0.58h
#
# Train--Epoch: 27, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 27, Step: 1058/1059	DDI Rate: 0.0813, Jaccard: 0.5151,  PRAUC: 0.7689, AVG_PRC: 0.6770, AVG_RECALL: 0.6928, AVG_F1: 0.6711
# training time: 90.93096780776978, test time: 14.935998439788818
# 	Epoch: 27, Loss: 0.2235, One Epoch Time: 1.52m, Appro Left Time: 0.56h
#
# Train--Epoch: 28, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 28, Step: 1058/1059	DDI Rate: 0.0811, Jaccard: 0.5159,  PRAUC: 0.7690, AVG_PRC: 0.6763, AVG_RECALL: 0.6950, AVG_F1: 0.6719
# training time: 90.76151943206787, test time: 14.849042654037476
# 	Epoch: 28, Loss: 0.2226, One Epoch Time: 1.51m, Appro Left Time: 0.53h
#
# Train--Epoch: 29, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 29, Step: 1058/1059	DDI Rate: 0.0807, Jaccard: 0.5161,  PRAUC: 0.7697, AVG_PRC: 0.6773, AVG_RECALL: 0.6939, AVG_F1: 0.6719
# training time: 91.42041325569153, test time: 14.784557104110718
# 	Epoch: 29, Loss: 0.2217, One Epoch Time: 1.52m, Appro Left Time: 0.51h
#
# Train--Epoch: 30, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 30, Step: 1058/1059	DDI Rate: 0.0804, Jaccard: 0.5162,  PRAUC: 0.7691, AVG_PRC: 0.6724, AVG_RECALL: 0.6992, AVG_F1: 0.6720
# training time: 90.9394223690033, test time: 14.785470008850098
# 	Epoch: 30, Loss: 0.2208, One Epoch Time: 1.52m, Appro Left Time: 0.48h
#
# Train--Epoch: 31, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 31, Step: 1058/1059	DDI Rate: 0.0793, Jaccard: 0.5154,  PRAUC: 0.7691, AVG_PRC: 0.6736, AVG_RECALL: 0.6965, AVG_F1: 0.6713
# training time: 90.98081517219543, test time: 14.737504959106445
# 	Epoch: 31, Loss: 0.2201, One Epoch Time: 1.52m, Appro Left Time: 0.45h
#
# Train--Epoch: 32, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 32, Step: 1058/1059	DDI Rate: 0.0773, Jaccard: 0.5159,  PRAUC: 0.7686, AVG_PRC: 0.6713, AVG_RECALL: 0.6997, AVG_F1: 0.6717
# training time: 91.35394644737244, test time: 15.079318761825562
# 	Epoch: 32, Loss: 0.2190, One Epoch Time: 1.52m, Appro Left Time: 0.43h
#
# Train--Epoch: 33, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 33, Step: 1058/1059	DDI Rate: 0.0795, Jaccard: 0.5161,  PRAUC: 0.7688, AVG_PRC: 0.6783, AVG_RECALL: 0.6921, AVG_F1: 0.6717
# training time: 91.78447699546814, test time: 14.805253982543945
# 	Epoch: 33, Loss: 0.2183, One Epoch Time: 1.53m, Appro Left Time: 0.41h
#
# Train--Epoch: 34, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 34, Step: 1058/1059	DDI Rate: 0.0802, Jaccard: 0.5169,  PRAUC: 0.7694, AVG_PRC: 0.6798, AVG_RECALL: 0.6926, AVG_F1: 0.6725
# training time: 91.37557792663574, test time: 14.766951322555542
# 	Epoch: 34, Loss: 0.2175, One Epoch Time: 1.52m, Appro Left Time: 0.38h
#
# Train--Epoch: 35, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 35, Step: 1058/1059	DDI Rate: 0.0805, Jaccard: 0.5157,  PRAUC: 0.7683, AVG_PRC: 0.6720, AVG_RECALL: 0.6985, AVG_F1: 0.6714
# training time: 91.95471262931824, test time: 15.02686619758606
# 	Epoch: 35, Loss: 0.2167, One Epoch Time: 1.53m, Appro Left Time: 0.36h
#
# Train--Epoch: 36, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 36, Step: 1058/1059	DDI Rate: 0.0784, Jaccard: 0.5161,  PRAUC: 0.7690, AVG_PRC: 0.6752, AVG_RECALL: 0.6960, AVG_F1: 0.6719
# training time: 91.76992583274841, test time: 14.851574420928955
# 	Epoch: 36, Loss: 0.2160, One Epoch Time: 1.53m, Appro Left Time: 0.33h
#
# Train--Epoch: 37, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 37, Step: 1058/1059	DDI Rate: 0.0781, Jaccard: 0.5155,  PRAUC: 0.7697, AVG_PRC: 0.6770, AVG_RECALL: 0.6929, AVG_F1: 0.6713
# training time: 91.06122517585754, test time: 14.670390129089355
# 	Epoch: 37, Loss: 0.2153, One Epoch Time: 1.52m, Appro Left Time: 0.30h
#
# Train--Epoch: 38, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 38, Step: 1058/1059	DDI Rate: 0.0791, Jaccard: 0.5160,  PRAUC: 0.7690, AVG_PRC: 0.6812, AVG_RECALL: 0.6901, AVG_F1: 0.6719
# training time: 91.09974884986877, test time: 14.709254503250122
# 	Epoch: 38, Loss: 0.2144, One Epoch Time: 1.52m, Appro Left Time: 0.28h
#
# Train--Epoch: 39, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 39, Step: 1058/1059	DDI Rate: 0.0803, Jaccard: 0.5147,  PRAUC: 0.7677, AVG_PRC: 0.6737, AVG_RECALL: 0.6952, AVG_F1: 0.6707
# training time: 91.67021656036377, test time: 14.849328517913818
# 	Epoch: 39, Loss: 0.2138, One Epoch Time: 1.53m, Appro Left Time: 0.25h
#
# Train--Epoch: 40, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 40, Step: 1058/1059	DDI Rate: 0.0799, Jaccard: 0.5148,  PRAUC: 0.7678, AVG_PRC: 0.6721, AVG_RECALL: 0.6975, AVG_F1: 0.6707
# training time: 91.18931460380554, test time: 14.803910970687866
# 	Epoch: 40, Loss: 0.2130, One Epoch Time: 1.52m, Appro Left Time: 0.23h
#
# Train--Epoch: 41, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 41, Step: 1058/1059	DDI Rate: 0.0784, Jaccard: 0.5159,  PRAUC: 0.7687, AVG_PRC: 0.6728, AVG_RECALL: 0.6982, AVG_F1: 0.6715
# training time: 91.14393424987793, test time: 14.830633640289307
# 	Epoch: 41, Loss: 0.2125, One Epoch Time: 1.52m, Appro Left Time: 0.20h
#
# Train--Epoch: 42, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 42, Step: 1058/1059	DDI Rate: 0.0794, Jaccard: 0.5144,  PRAUC: 0.7677, AVG_PRC: 0.6779, AVG_RECALL: 0.6902, AVG_F1: 0.6703
# training time: 91.28439450263977, test time: 14.847147464752197
# 	Epoch: 42, Loss: 0.2119, One Epoch Time: 1.52m, Appro Left Time: 0.18h
#
# Train--Epoch: 43, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 43, Step: 1058/1059	DDI Rate: 0.0803, Jaccard: 0.5135,  PRAUC: 0.7681, AVG_PRC: 0.6761, AVG_RECALL: 0.6912, AVG_F1: 0.6695
# training time: 90.5172598361969, test time: 14.546104192733765
# 	Epoch: 43, Loss: 0.2113, One Epoch Time: 1.51m, Appro Left Time: 0.15h
#
# Train--Epoch: 44, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 44, Step: 1058/1059	DDI Rate: 0.0786, Jaccard: 0.5161,  PRAUC: 0.7680, AVG_PRC: 0.6740, AVG_RECALL: 0.6972, AVG_F1: 0.6718
# training time: 89.97632360458374, test time: 14.505601406097412
# 	Epoch: 44, Loss: 0.2107, One Epoch Time: 1.50m, Appro Left Time: 0.12h
#
# Train--Epoch: 45, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 45, Step: 1058/1059	DDI Rate: 0.0789, Jaccard: 0.5152,  PRAUC: 0.7681, AVG_PRC: 0.6721, AVG_RECALL: 0.6979, AVG_F1: 0.6709
# training time: 90.5590603351593, test time: 14.877618551254272
# 	Epoch: 45, Loss: 0.2102, One Epoch Time: 1.51m, Appro Left Time: 0.10h
#
# Train--Epoch: 46, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 46, Step: 1058/1059	DDI Rate: 0.0793, Jaccard: 0.5149,  PRAUC: 0.7676, AVG_PRC: 0.6767, AVG_RECALL: 0.6924, AVG_F1: 0.6707
# training time: 92.1278715133667, test time: 14.57914662361145
# 	Epoch: 46, Loss: 0.2094, One Epoch Time: 1.54m, Appro Left Time: 0.08h
#
# Train--Epoch: 47, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 47, Step: 1058/1059	DDI Rate: 0.0802, Jaccard: 0.5147,  PRAUC: 0.7663, AVG_PRC: 0.6708, AVG_RECALL: 0.6982, AVG_F1: 0.6705
# training time: 91.56228709220886, test time: 14.70695424079895
# 	Epoch: 47, Loss: 0.2088, One Epoch Time: 1.53m, Appro Left Time: 0.05h
#
# Train--Epoch: 48, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 48, Step: 1058/1059	DDI Rate: 0.0775, Jaccard: 0.5158,  PRAUC: 0.7676, AVG_PRC: 0.6693, AVG_RECALL: 0.7014, AVG_F1: 0.6713
# training time: 90.59289574623108, test time: 14.669657468795776
# 	Epoch: 48, Loss: 0.2084, One Epoch Time: 1.51m, Appro Left Time: 0.03h
#
# Train--Epoch: 49, Step: 4232/4233, L_p cnt: 0, L_neg cnt: 0
# Eval--Epoch: 49, Step: 1058/1059	DDI Rate: 0.0779, Jaccard: 0.5141,  PRAUC: 0.7667, AVG_PRC: 0.6692, AVG_RECALL: 0.6991, AVG_F1: 0.6698
# training time: 90.74847793579102, test time: 14.709624290466309
# 	Epoch: 49, Loss: 0.2078, One Epoch Time: 1.51m, Appro Left Time: 0.00h
#
# best_epoch: 34

# %%
import pickle
with open(os.path.join('saved', args.model_name, 'history.pkl'), 'rb') as f:
  fin = pickle.load(f)

# %%
import numpy as np
print('Average Training time is: {}'.format(np.average(fin['train_time'])))
print('Average Memory Usage is: {}'.format(np.average(fin['memory'])))
print('Average DDI is {}, Std DDI is {}'.format(np.average(fin['ddi_rate']), np.std(fin['ddi_rate'])))
print('Average Jaccard is {}, Std Jaccard is {}'.format(np.average(fin['ja']), np.std(fin['ja'])))
# Out:
# Average Training time is: 90.12035519123077
# Average Memory Usage is: 7.38232421875
# Average DDI is 0.08080003017067322, Std DDI is 0.0030441389489791115
# Average Jaccard is 0.5065718727842071, Std Jaccard is 0.01613608362497081
